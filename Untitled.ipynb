# %%
import pandas as pd
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
crypto_df = pd.read_csv('resources/crypto_data.csv')

# %%
crypto_df
# Out:
#      Unnamed: 0        CoinName Algorithm  IsTrading ProofType  \
# 0            42         42 Coin    Scrypt       True   PoW/PoS
# 1           365         365Coin       X11       True   PoW/PoS
# 2           404         404Coin    Scrypt       True   PoW/PoS
# 3           611       SixEleven   SHA-256       True       PoW
# 4           808             808   SHA-256       True   PoW/PoS
# ...         ...             ...       ...        ...       ...
# 1247        XBC     BitcoinPlus    Scrypt       True       PoS
# 1248       DVTC      DivotyCoin    Scrypt      False   PoW/PoS
# 1249       GIOT     Giotto Coin    Scrypt      False   PoW/PoS
# 1250       OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS
# 1251       PUNK       SteamPunk       PoS      False       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# ...

# %%
crypto_df_v2 = crypto_df[crypto_df.IsTrading != False]

# %%
crypto_df_v2.drop(columns=['IsTrading'], axis=1)
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 1           365      365Coin          X11   PoW/PoS              NaN
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 3           611    SixEleven      SHA-256       PoW              NaN
# 4           808          808      SHA-256   PoW/PoS     0.000000e+00
# ...         ...          ...          ...       ...              ...
# 1243       SERO   Super Zero       Ethash       PoW              NaN
# 1244        UOS          UOS      SHA-256      DPoI              NaN
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# 4                  0
# ...

# %%
crypto_df_v3 = crypto_df_v2.dropna()

# %%
crypto_df_v3
# Out:
#      Unnamed: 0     CoinName    Algorithm  IsTrading ProofType  \
# 0            42      42 Coin       Scrypt       True   PoW/PoS
# 2           404      404Coin       Scrypt       True   PoW/PoS
# 4           808          808      SHA-256       True   PoW/PoS
# 5          1337    EliteCoin          X13       True   PoW/PoS
# 7           BTC      Bitcoin      SHA-256       True       PoW
# ...         ...          ...          ...        ...       ...
# 1238       ZEPH       ZEPHYR      SHA-256       True      DPoS
# 1242        GAP      Gapcoin       Scrypt       True   PoW/PoS
# 1245        BDX       Beldex  CryptoNight       True       PoW
# 1246        ZEN      Horizen     Equihash       True       PoW
# 1247        XBC  BitcoinPlus       Scrypt       True       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 2        1.055185e+09       532000000
# 4        0.000000e+00               0
# 5        2.927942e+10    314159265359
# ...

# %%
crypto_df_v4 = crypto_df_v3[crypto_df_v3['TotalCoinsMined'] > 0]

# %%
crypto_df_v4
# Out:
#      Unnamed: 0     CoinName    Algorithm  IsTrading ProofType  \
# 0            42      42 Coin       Scrypt       True   PoW/PoS
# 2           404      404Coin       Scrypt       True   PoW/PoS
# 5          1337    EliteCoin          X13       True   PoW/PoS
# 7           BTC      Bitcoin      SHA-256       True       PoW
# 8           ETH     Ethereum       Ethash       True       PoW
# ...         ...          ...          ...        ...       ...
# 1238       ZEPH       ZEPHYR      SHA-256       True      DPoS
# 1242        GAP      Gapcoin       Scrypt       True   PoW/PoS
# 1245        BDX       Beldex  CryptoNight       True       PoW
# 1246        ZEN      Horizen     Equihash       True       PoW
# 1247        XBC  BitcoinPlus       Scrypt       True       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 2        1.055185e+09       532000000
# 5        2.927942e+10    314159265359
# 7        1.792718e+07        21000000
# ...

# %%
crypto_df_v4.drop(columns=['CoinName'], axis=1)
# Out:
#      Unnamed: 0    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0            42       Scrypt       True   PoW/PoS     4.199995e+01
# 2           404       Scrypt       True   PoW/PoS     1.055185e+09
# 5          1337          X13       True   PoW/PoS     2.927942e+10
# 7           BTC      SHA-256       True       PoW     1.792718e+07
# 8           ETH       Ethash       True       PoW     1.076842e+08
# ...         ...          ...        ...       ...              ...
# 1238       ZEPH      SHA-256       True      DPoS     2.000000e+09
# 1242        GAP       Scrypt       True   PoW/PoS     1.493105e+07
# 1245        BDX  CryptoNight       True       PoW     9.802226e+08
# 1246        ZEN     Equihash       True       PoW     7.296538e+06
# 1247        XBC       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 5       314159265359
# 7           21000000
# 8                  0
# ...              ...
# ...
